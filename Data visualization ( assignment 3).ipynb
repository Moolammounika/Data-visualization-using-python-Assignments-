# %% [markdown]
# ###  Que 1

# %%
#importing the libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the data
data=sns.load_dataset('fmri')

# %%
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
#for knowing the shape
data.shape
# Out:
# (1064, 5)

# %%
#for column names
data.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
#for knowing the datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
#for describing the data
data.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %% [markdown]
# ### Relation plot

# %%
sns.relplot(x="timepoint",y="signal",data=data)

# %%
#using hue
sns.relplot(x="timepoint",y="signal",data=data,hue='region')

# %%
sns.relplot(x="timepoint",y="signal",data=data,hue='region',style='event',size='subject')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=data,sort=True,hue='region',style='event')

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x="timepoint",y="signal",data=data,hue='region')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>
